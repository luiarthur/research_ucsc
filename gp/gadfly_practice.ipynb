# %%
using Gadfly, RCall
set_default_plot_size(20cm, 12.35cm) # GOLDEN RATIO
srand(123);
# Out:
# INFO: Recompiling stale cache file /home/juser/.julia/lib/v0.4/RCall.ji for module RCall.
# R installation found at "/usr/lib/R"

# %%
p = plot(x=randn(2000), Geom.histogram(bincount=20), Theme(bar_spacing=.3mm))
# Out:
# Plot(...)

# %%
?Theme
# Out:
# search:
# WARNING: both DataArrays and StatsBase export "autocor"; uses of it in module DataFrames must be qualified
# WARNING: both DataArrays and StatsBase export "inverse_rle"; uses of it in module DataFrames must be qualified
# WARNING: both DataArrays and StatsBase export "rle"; uses of it in module DataFrames must be qualified
# No documentation found.
#
# **Summary:**
#
# ```julia
# type Gadfly.Theme <: Any
# ```
#
# **Fields:**
#
# ```julia
# default_color               :: Union{ColorTypes.Colorant{T,N},Void}
# default_point_size          :: Measures.Measure
# line_width                  :: Measures.Measure
# line_style                  :: Union{Array{T,1},Void}
# panel_fill                  :: Union{ColorTypes.Colorant{T,N},Void}
# panel_stroke                :: Union{ColorTypes.Colorant{T,N},Void}
# panel_opacity               :: Float64
# background_color            :: Union{ColorTypes.Colorant{T,N},Void}
# plot_padding                :: Measures.Measure
# ...

# %%
n = 50
y = randn(n)
ylo = y - 1
yhi = y + 10
plot(x=1:n,y=randn(100), ymin=ylo, ymax=yhi, Geom.errorbar)
# Out:
# Plot(...)

# %%
using ChoroplethMaps
using DataFrames

# The data we want to map thematically
df = DataFrame(NAME=["Alabama", "Arkansas", "Louisiana", "Mississippi", "Tennessee"],
PCT=[26.6673430422, 15.6204437142, 32.4899197277, 37.5052896066, 17.0874767458] )

plot(mapify(df, Provider.STATESUMMARY(), key=:NAME),
     x=:CM_X, y=:CM_Y, group=:NAME, color=:PCT,
     Geom.polygon(preserve_order=true, fill=true),
     Coord.cartesian(fixed=true))
# Out:
# LoadError: ArgumentError: ChoroplethMaps not found in path
# while loading In[5], in expression starting on line 1
#
#  in require at ./loading.jl:249

# %%
plot(mapify(df, Provider.STATESUMMARY(), key=:NAME),
     x=:CM_X, y=:CM_Y, group=:NAME,
     Geom.polygon(preserve_order=true, fill=true),
     Coord.cartesian(fixed=true))
# Out:
# LoadError: UndefVarError: mapify not defined
# while loading In[6], in expression starting on line 1

# %%
p1=layer(mapify(df, Provider.STATESUMMARY(), key=:NAME),
        x=:CM_X, y=:CM_Y, group=:NAME,
        Geom.polygon(preserve_order=true, fill=true)) 
p2= layer(x=[-1.08*10^7],y=[4e6], Geom.point)
plot(p1,p2)
# Out:
# LoadError: UndefVarError: mapify not defined
# while loading In[7], in expression starting on line 1

# %%
using Plots
#gadfly()
gadfly(size=(1000,400))
scatter(randn(100))
# Out:
# WARNING: using Plots.plot in module Main conflicts with an existing identifier.
# [Plots.jl] Initializing backend: gadfly
# ...

# %%
Plots.plot(randn(100))
# Out:
# Compose.SVG(264.5502645502646mm,105.82010582010584mm,IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=4486, maxsize=Inf, ptr=4487, mark=-1),nothing,"img-3e12d245",0,Compose.SVGPropertyFrame[],Dict{Type{T},Union{Compose.Property{P<:Compose.PropertyPrimitive},Void}}(),Dict{Compose.ClipPrimitive{P<:NTuple{N,Measures.Measure}},ASCIIString}(Compose.ClipPrimitive{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}([(5.506666666666661mm,1.0mm),(256.75359788359793mm,1.0mm),(256.75359788359793mm,100.18677248677251mm),(5.506666666666661mm,100.18677248677251mm)])=>"img-3e12d245-8"),Tuple{Compose.FormPrimitive,ASCIIString}[],Set{AbstractString}(),true,false,nothing,true,"img-3e12d245-15",false,15,AbstractString["/home/juser/.julia/v0.4/Gadfly/src/gadfly.js"],Tuple{AbstractString,AbstractString}[("Snap.svg","Snap"),("Gadfly","Gadfly")],AbstractString["fig.select(\"#img-3e12d245-4\")\n   .drag(function() {}, function() {}, function() {});","fi
# ...

# %% [markdown]
# ![image](tmp.svg)

# %%
using RCall
@rlibrary(graphics)
@rlibrary(maps)
# Changed ijulia_init() to include a width and height parameter to change plot size. Also need to export
# ijulia_init() by adding it in the exports in setup.jl within the IJulia directory.
#ijulia_init(8,5)
map("county");

# %%
xx = randn(100)
R"plot($xx,fg='grey',bty='n',pch=20,col='cornflowerblue',cex=2)"
# Out:
# RCall.RObject{RCall.NilSxp}
# NULL
