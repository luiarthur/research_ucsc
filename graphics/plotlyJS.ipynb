# %%
using PlotlyJS;

# %%
function scatter_3d()
    @eval using Distributions
    Σ = fill(0.5, 3, 3) + Diagonal([0.5, 0.5, 0.5])
    obs1 = rand(MvNormal(zeros(3), Σ), 200)'
    obs2 = rand(MvNormal(zeros(3), 0.5Σ), 100)'

    trace1 = scatter3d(;x=obs1[:, 1], y=obs1[:, 2], z=obs1[:, 3],
                        mode="markers", opacity=0.8,
                        marker_size=12, marker_line_width=0.5,
                        marker_line_color="rgba(217, 217, 217, 0.14)")

    trace2 = scatter3d(;x=obs2[:, 1], y=obs2[:, 2], z=obs2[:, 3],
                        mode="markers", opacity=0.9,
                        marker=attr(color="rgb(127, 127, 127)",
                                    symbol="circle", line_width=1.0,
                                    line_color="rgb(204, 204, 204)"))

    layout = Layout(margin=attr(l=0, r=0, t=0, b=0))

    plot([trace1, trace2], layout)
end
# Out:
# scatter_3d (generic function with 1 method)

# %%
scatter_3d()
# Out:
# <div id="8008aa91-07d8-4703-bc2f-6e624001e602" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('8008aa91-07d8-4703-bc2f-6e624001e602', [{"type":"scatter3d","y":[-0.9227238748871449,0.1059903632137978,0.1501436310660529,1.0716831151600745,-0.2932058020934187,-1.560633681486925,1.6447845155131497,-0.4657043014373259,0.10982089131321571,-0.8358721353679857,-0.4937282038990328,-0.12001269538759235,1.089937150129574,0.5498989176648865,0.9191266353987138,0.42949845665046454,-0.3177163943412509,-0.9912967130660555,1.5489323505456438,-1.4511958578154613,0.08959326176515137,-0.8441825241816654,0.01453847507084026,-0.2958774956395541,0.28491989633948456,-0.7103436210243865,0.39949146008913805,-0.5400429424518941,0.9540482557150964,0.8387819887530497,0.7330441737899368,0.16877483350878827,-0.021099737724391776,0.24684693506819755,-1.2418390254776157,1.0085125411876614,-1.327951366073845,0.5164118604852714,-1.124805235071327,-0.9719404719214273,-0.4462182947948586,-0.6575677313596175,1.2009268040159418,0.0870700620862892,-1.0270486687762397,0.08369881751953367,0.31059238138972356,0.35712650801266627,-1.0893699597251492,0.25450171286123124,-0.13381834531649975,2.392696474213598,1.5738106880083451,-0.25763410819961197,0.06000182142531724,1.9855054259686407,-0.2623257509098725,-0.4844753405885426,0.7861673001843548,-2.508594526626158,-2.004077640684746,0.20672675161377274,-0.08503913486499065,-0.22208049811515385,0.09690311840527555,-1.0914052684088964,1.3222640012076983,0.09801336054241627,-0.25779376137103227,-0.14854880397805761,-0.1975686964021337,-0.47525155372383177,-1.3753297998162037,0.0023232397177158637,0.03121849678863603,1.1924080133243553,-0.7120110190377337,-0.08952958694339944,-0.8571954590456451,-0.19474438014812107,-1.2746787070893457,0.30431190893017723,-0.9437752252826914,-2.4351642845702015,-0.8254690666609296,0.24781621267035125,-0.276838989352565,2.3344635254020023,-0.5315298914852906,1.828029289945336,1.0062964638078435,0.7470387741450784,-1.3487522443151279,-0.8482524175062872,0.5923919729619431,0.3841439635902639,-1.056534698540192,0.040432474971525245,1.3595138470316552,0.3153362677559052,0.1072778263328007,0.4714990393901114,-0.2650761673310621,-1.1703744619832066,0.8979957139838264,0.12752229486224378,-1.003813782977572,0.25384723266725756,1.3707806420292987,-1.8832527314347083,0.5947260844811035,-0.4797786613576367,1.0454606479199313,0.297716824793936,-0.46702840438782584,-0.7790121132509588,-0.2978561867746019,0.8619768741482955,-0.6867035772272314,0.46686522399542363,0.09487952946779404,-0.1565759450045281,-0.7834687177470345,0.9825084595760727,1.0930740291705294,-1.6847987912975122,0.5129859710008147,1.0216336262806462,0.9536918429321098,0.11411128913458546,0.4451827325441028,0.0678991475151656,1.3253667051777809,1.2192188956079353,-0.32220619761670655,0.29309600849947304,0.7400725883602339,-1.523385244708113,-1.210089025780408,1.3920734203205494,0.016222241338060328,0.2290668103345353,-0.5896193726713983,0.7967238487177943,1.1307551173192314,1.0921298748382524,-0.0201683756800759,-1.3080859553367605,-0.19509381295714637,2.645593688957418,0.08256410158025129,-0.031833294899066944,0.2172628826668596,-0.1674231906443679,0.40423216495420766,1.526089617524319,0.7018367607801129,-0.3205466048948751,1.0318431866777735,0.23802510091001883,0.9598302761477805,2.1506269374257014,0.908669537722261,0.8483372529994511,0.5425042827192446,-1.1772327161181448,0.3597957994838191,1.375324022645468,-2.0435213991141308,0.5330585001465029,1.339469983612144,0.28225633841906517,-0.30842881119551246,1.1526559932739575,-0.623143696182853,0.8184105733418318,1.4310003899919845,0.024557759515009936,-1.0154231033441998,1.5993844180625354,0.4693971995087758,1.220430256143493,1.7589219838291494,-0.07183497751493717,-1.237766316992589,-0.6022221024568211,1.5069785441950183,-1.0826974594368657,-1.1806610154370836,0.6210670199274484,0.6921409418304032,-0.5343818737402071,-0.2642126374175664,1.0514501872604982,0.5312289850514028,0.9065682032110582,0.11399653602282865,-0.6179823670029168,-1.4087054025823473,0.204812 ...

# %%
function maps1()
    marker = attr(size=[20, 30, 15, 10],
                  color=[10, 20, 40, 50],
                  cmin=0,
                  cmax=50,
                  colorscale="Greens",
                  colorbar=attr(title="Some rate",
                                ticksuffix="%",
                                showticksuffix="last"),
                  line_color="black")
    trace = scattergeo(;mode="markers", locations=["FRA", "DEU", "RUS", "ESP"],
                        marker=marker, name="Europe Data")
    #layout = Layout(geo_scope="europe", geo_resolution=50, width=1000, height=550,
    layout = Layout(geo_scope="europe", geo_resolution=50,
                    margin=attr(l=0, r=0, t=10, b=0))
    plot(trace, layout)
end
# Out:
# maps1 (generic function with 1 method)

# %%
maps1()
# Out:
# <div id="caf0f74f-c40b-43c6-9d39-4481bb45377a" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('caf0f74f-c40b-43c6-9d39-4481bb45377a', [{"type":"scattergeo","name":"Europe Data","mode":"markers","locations":["FRA","DEU","RUS","ESP"],"marker":{"cmin":0,"colorscale":"Greens","line":{"color":"black"},"size":[20,30,15,10],"colorbar":{"ticksuffix":"%","showticksuffix":"last","title":"Some rate"},"color":[10,20,40,50],"cmax":50}}],  {"geo":{"resolution":50,"scope":"europe"},"margin":{"r":0,"l":0,"b":0,"t":10}}, {showLink: false});
#
#     });
#  </script>

# %%
t1 = scatter(;x=[1, 2, 3, 4, 5], y=[1, 6, 3, 6, 1])
# Out:
# scatter with fields x and y

# %%
plot(t1)
# Out:
# <div id="911274f7-ab3c-4033-95e1-274b247b7eb7" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('911274f7-ab3c-4033-95e1-274b247b7eb7', [{"type":"scatter","y":[1,6,3,6,1],"x":[1,2,3,4,5]}],  {"margin":{"r":50,"l":50,"b":50,"t":60}}, {showLink: false});
#
#     });
#  </script>
